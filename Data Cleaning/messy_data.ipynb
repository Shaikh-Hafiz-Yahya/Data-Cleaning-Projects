# %% [markdown]
# # Messy_DataSet

# %%
import pandas as pd
import numpy as np

# 1. Messy Dataset create
data = {
    'Customer_ID': [101, 102, 103, 101, 105, 106, 107, 108],
    'Name': ['Ahmed', 'Sara', 'Zain', 'Ahmed', 'Fatima', '  Usman  ', 'Hamza', None],
    'Age': [25, 30, 22, 25, 28, 35, 250, 29], 
    'City': ['Karachi', 'Lahore', 'Islamabad', 'Karachi', 'karachi', 'Lahore', 'Peshawar', 'Quetta'],
    'Spent_Amount': [5000, 7000, None, 5000, 12000, 8500, 9000, 6000],
    'Join_Date': ['2023-01-01', '2023-01-05', '2023-01-10', '2023-01-01', '2023-02-01', '2023-02-15', '2023-03-01', '2023-03-05']
}

df = pd.DataFrame(data)
df.to_csv('messy_customer_data.csv', index=False)
print("Dataset create ho gaya! Ab aap is par cleaning shuru karein.")
# Out:
# Dataset create ho gaya! Ab aap is par cleaning shuru karein.
